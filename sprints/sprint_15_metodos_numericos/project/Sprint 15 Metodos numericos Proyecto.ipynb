# %% [markdown]
# El servicio de venta de autos usados Rusty Bargain está desarrollando una aplicación para atraer nuevos clientes. Gracias a esa app, puedes averiguar rápidamente el valor de mercado de tu coche. Tienes acceso al historial: especificaciones técnicas, versiones de equipamiento y precios. Tienes que crear un modelo que determine el valor de mercado.
# A Rusty Bargain le interesa:
# - la calidad de la predicción;
# - la velocidad de la predicción;
# - el tiempo requerido para el entrenamiento

# %% [markdown]
# ## Preparación de datos

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from time import process_time
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from time import process_time

# %%
# Cargar datos

df = pd.read_csv('/datasets/car_data.csv')

# %%
df.sample(5)
# Out:
#              DateCrawled  Price  VehicleType  RegistrationYear Gearbox  Power  \
# 293056  05/04/2016 21:36   1100        wagon              2000  manual     90
# 62453   07/03/2016 09:53      0        small              1994  manual     70
# 137427  01/04/2016 13:44   1800  convertible              2002  manual     90
# 34623   05/04/2016 11:52    790        small              1997  manual     75
# 276965  23/03/2016 15:57   1500          bus              1991  manual      0
#
#               Model  Mileage  RegistrationMonth  FuelType       Brand  \
# 293056        focus   150000                  6  gasoline        ford
# 62453        cooper     5000                  6    petrol        mini
# 137427      2_reihe   100000                  9    petrol     peugeot
# 34623         other   150000                  3    petrol      toyota
# 276965  transporter   150000                 11       NaN  volkswagen
#
#        NotRepaired       DateCreated  NumberOfPictures  PostalCode  \
# 293056          no  05/04/2016 00:00                 0       58099
# 62453           no  07/03/2016 00:00                 0       54329
# 137427          no  01/04/2016 00:00                 0        9456
# 34623           no  05/04/2016 00:00                 0       83257
# 276965         yes  23/03/2016 00:00                 0       31867
#
#                 LastSeen
# 293056  05/04/2016 21:36
# 62453   08/03/2016 16:20
# 137427  01/04/2016 13:44
# 34623   05/04/2016 12:42
# 276965  26/03/2016 09:45

# %%
# Valores ausentes

df.isna().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37490
# RegistrationYear         0
# Gearbox              19833
# Power                    0
# Model                19705
# Mileage                  0
# RegistrationMonth        0
# FuelType             32895
# Brand                    0
# NotRepaired          71154
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %%
# Filas duplicadas

df.duplicated().sum()
# Out:
# 262

# %%
# Tipo de datos de cada columna

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
# Reemplazar valores ausentes con 'unknown'

df.fillna('Unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# DateCrawled          0
# Price                0
# VehicleType          0
# RegistrationYear     0
# Gearbox              0
# Power                0
# Model                0
# Mileage              0
# RegistrationMonth    0
# FuelType             0
# Brand                0
# NotRepaired          0
# DateCreated          0
# NumberOfPictures     0
# PostalCode           0
# LastSeen             0
# dtype: int64

# %%
# Remover filas duplicadas

df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Remover columnas irrelevantes

irrelevant_fields = ['DateCrawled', 'RegistrationMonth', 'DateCreated', 'NumberOfPictures', 'LastSeen']

df.drop(irrelevant_fields, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Price', 'VehicleType', 'RegistrationYear', 'Gearbox', 'Power', 'Model',
#        'Mileage', 'FuelType', 'Brand', 'NotRepaired', 'PostalCode'],
#       dtype='object')

# %%
# Convertir campos categóricos a campos numéricos

categorical_fields = ['VehicleType','Gearbox','Model','FuelType','Brand','NotRepaired']

df_ohe = pd.get_dummies(df, columns=categorical_fields, drop_first=True)

# %%
df_ohe.sample(5)
# Out:
#         Price  RegistrationYear  Power  Mileage  PostalCode  VehicleType_bus  \
# 41030    1850              1996      0   150000       31303                1
# 350333   8950              2006    209   100000       86637                0
# 304922  14599              2012    170   150000       58332                1
# 269609   3399              2006    101   150000       23879                0
# 8819      900              1998     60   150000        7985                0
#
#         VehicleType_convertible  VehicleType_coupe  VehicleType_other  \
# 41030                         0                  0                  0
# 350333                        0                  0                  0
# 304922                        0                  0                  0
# 269609                        0                  0                  0
# 8819                          0                  0                  0
#
#         VehicleType_sedan  ...  Brand_smart  Brand_sonstige_autos  \
# 41030                   0  ...            0                     0
# 350333                  1  ...            0                     0
# 304922                  0  ...            0                     0
# 269609                  0  ...            0                     0
# 8819                    0  ...            0                     0
#
#         Brand_subaru  Brand_suzuki  Brand_toyota  Brand_trabant  \
# 41030              0             0             0              0
# 350333             0             0             0              0
# 304922             0             0             0              0
# 269609             0             0             0              0
# 8819               0             0             0              0
#
#         Brand_volkswagen  Brand_volvo  NotRepaired_no  NotRepaired_yes
# 41030                  0            0               1                0
# 350333                 0            1               1                0
# 304922                 0            0               1                0
# 269609                 0            0               1                0
# 8819                   0            0               1                0
#
# [5 rows x 313 columns]

# %%
# Separar data

X = df_ohe.drop('Price', axis=1)
y = df_ohe['Price']

# %%
X_train, X_test_valid, y_train, y_test_valid = train_test_split(X, y, test_size=0.40, random_state=12345)
X_test, X_valid, y_test, y_valid = train_test_split(X_test_valid, y_test_valid, test_size=0.50, random_state=12345)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (212464, 312)
# (212464,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (70821, 312)
# (70821,)

# %%
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (70822, 312)
# (70822,)

# %%
# Escalamiento

features_to_scale = ['RegistrationYear', 'Power', 'Mileage']

transformer = StandardScaler().fit(X_train[features_to_scale].to_numpy())

# %%
X_train_scaled = X_train.copy()
X_train_scaled.loc[:,features_to_scale] = transformer.transform(X_train[features_to_scale].to_numpy())

# %%
X_valid_scaled = X_valid.copy()
X_valid_scaled.loc[:,features_to_scale] = transformer.transform(X_valid[features_to_scale].to_numpy())

# %%
X_test_scaled = X_test.copy()
X_test_scaled.loc[:,features_to_scale] = transformer.transform(X_test[features_to_scale].to_numpy())

# %% [markdown]
# ## Entrenamiento del modelo

# %%
# %%time
# Regresion lineal

model = LinearRegression()
model.fit(X_train, y_train)

predicted_values = model.predict(X_valid)

RMSE = np.sqrt(mean_squared_error(y_valid, predicted_values))

print('Error caudarado medio de la regresión linear es ', round(RMSE,2))
print('Tiempo para la regresión lineal:')
# Out:
# Error caudarado medio de la regresión linear es  3162.68
# Tiempo para la regresión lineal:
# CPU times: user 9.39 s, sys: 3.97 s, total: 13.4 s
# Wall time: 7.05 s

# %%
#Funcion para evaluar diferentes modelos con distintos hiperparámetros

def model_eval(model, model_name):
    
    parameters = {'n_estimators':[5, 10, 20],
                 'max_depth': [5, 10, 20]}

    model = model

    model_grid = GridSearchCV(model, param_grid=parameters, cv=3, scoring='neg_root_mean_squared_error', verbose=0)

    model_grid.fit(X_train, y_train)

    best_parameters = model_grid.best_params_

    best_score = model_grid.best_score_

    best_grid = model_grid.best_estimator_

    predictes_values = best_grid.predict(X_valid)

    RMSE = np.sqrt(mean_squared_error(y_valid, predicted_values))

    print('Mejores parametros para', model_name, ":", best_parameters)
    print('RMSE con datos de entrenamiento', round(best_score,2))
    print('RMSE con datos de validación', round(RMSE,2))
    print('Tiempo de entrenamiento para', model_name, ':')

# %% [markdown]
# %%time
#
# # RandomForest
#
# model = RandomForestRegressor()
# model_name = 'RandomForestRegressor'
#
# model_eval(model, model_name)

# %%
# %%time

# LightGBM

model = LGBMRegressor(random_state=12345)
model_name = 'LightGBMRegressor'

model_eval(model, model_name)
# Out:
# Mejores parametros para LightGBMRegressor : {'max_depth': 20, 'n_estimators': 20}
# RMSE con datos de entrenamiento -2217.07
# RMSE con datos de validación 3162.68
# Tiempo de entrenamiento para LightGBMRegressor :
# CPU times: user 55.1 s, sys: 4.07 s, total: 59.2 s
# Wall time: 36.6 s

# %%
# %%time

# CatBoost

model = CatBoostRegressor(random_state=12345)
model_name = 'CatBootRegressor'

model_eval(model, model_name)
# Out:
# Learning rate set to 0.5
# 0:	learn: 3385.5863119	total: 52ms	remaining: 208ms
# 1:	learn: 2856.0259970	total: 56.9ms	remaining: 85.4ms
# 2:	learn: 2562.1711323	total: 61.5ms	remaining: 41ms
# 3:	learn: 2433.2242960	total: 65.8ms	remaining: 16.5ms
# 4:	learn: 2349.1954520	total: 70.1ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3372.0967743	total: 5.22ms	remaining: 20.9ms
# 1:	learn: 2850.0901721	total: 55.5ms	remaining: 83.2ms
# 2:	learn: 2598.0591684	total: 60ms	remaining: 40ms
# 3:	learn: 2436.4944153	total: 64.2ms	remaining: 16.1ms
# 4:	learn: 2353.6532274	total: 68.3ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3382.2333646	total: 5.31ms	remaining: 21.2ms
# 1:	learn: 2853.6776925	total: 10ms	remaining: 15ms
# 2:	learn: 2563.1154861	total: 14.5ms	remaining: 9.64ms
# 3:	learn: 2439.5803922	total: 19.1ms	remaining: 4.78ms
# 4:	learn: 2358.3116835	total: 63.6ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3385.5863119	total: 5.08ms	remaining: 45.7ms
# 1:	learn: 2856.0259970	total: 10.3ms	remaining: 41.2ms
# 2:	learn: 2562.1711323	total: 60.4ms	remaining: 141ms
# 3:	learn: 2433.2242960	total: 64.9ms	remaining: 97.3ms
# 4:	learn: 2349.1954520	total: 69.3ms	remaining: 69.3ms
# 5:	learn: 2298.6450957	total: 73.8ms	remaining: 49.2ms
# 6:	learn: 2258.5129219	total: 78.2ms	remaining: 33.5ms
# 7:	learn: 2230.4099971	total: 82.6ms	remaining: 20.7ms
# 8:	learn: 2192.3411116	total: 159ms	remaining: 17.7ms
# 9:	learn: 2167.0983141	total: 164ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3372.0967743	total: 5.08ms	remaining: 45.7ms
# 1:	learn: 2850.0901721	total: 9.79ms	remaining: 39.2ms
# 2:	learn: 2598.0591684	total: 14.5ms	remaining: 33.7ms
# 3:	learn: 2436.4944153	total: 18.8ms	remaining: 28.2ms
# 4:	learn: 2353.6532274	total: 23.8ms	remaining: 23.8ms
# 5:	learn: 2308.7105563	total: 65.7ms	remaining: 43.8ms
# 6:	learn: 2257.9699209	total: 69.8ms	remaining: 29.9ms
# 7:	learn: 2224.8192483	total: 74.4ms	remaining: 18.6ms
# 8:	learn: 2202.4993997	total: 78.3ms	remaining: 8.7ms
# 9:	learn: 2178.3187492	total: 82.4ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3382.2333646	total: 5.7ms	remaining: 51.3ms
# 1:	learn: 2853.6776925	total: 10.8ms	remaining: 43ms
# 2:	learn: 2563.1154861	total: 15ms	remaining: 35ms
# 3:	learn: 2439.5803922	total: 19.4ms	remaining: 29ms
# 4:	learn: 2358.3116835	total: 29.1ms	remaining: 29.1ms
# 5:	learn: 2312.4808790	total: 64.8ms	remaining: 43.2ms
# 6:	learn: 2267.7329502	total: 68.9ms	remaining: 29.5ms
# 7:	learn: 2225.0594943	total: 73.4ms	remaining: 18.4ms
# 8:	learn: 2196.2478361	total: 77.5ms	remaining: 8.62ms
# 9:	learn: 2177.7973708	total: 81.7ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3385.5863119	total: 5.21ms	remaining: 99.1ms
# 1:	learn: 2856.0259970	total: 9.88ms	remaining: 89ms
# 2:	learn: 2562.1711323	total: 14.2ms	remaining: 80.6ms
# 3:	learn: 2433.2242960	total: 18.5ms	remaining: 73.9ms
# 4:	learn: 2349.1954520	total: 28.2ms	remaining: 84.7ms
# 5:	learn: 2298.6450957	total: 62.5ms	remaining: 146ms
# 6:	learn: 2258.5129219	total: 66.9ms	remaining: 124ms
# 7:	learn: 2230.4099971	total: 71.4ms	remaining: 107ms
# 8:	learn: 2192.3411116	total: 75.8ms	remaining: 92.7ms
# 9:	learn: 2167.0983141	total: 80.2ms	remaining: 80.2ms
# 10:	learn: 2143.9522670	total: 84ms	remaining: 68.8ms
# 11:	learn: 2127.9451468	total: 93.5ms	remaining: 62.3ms
# 12:	learn: 2113.2741461	total: 165ms	remaining: 88.7ms
# 13:	learn: 2102.1595777	total: 169ms	remaining: 72.4ms
# 14:	learn: 2093.4173138	total: 173ms	remaining: 57.6ms
# 15:	learn: 2082.0376378	total: 177ms	remaining: 44.3ms
# 16:	learn: 2067.3275304	total: 182ms	remaining: 32.1ms
# 17:	learn: 2054.9203195	total: 195ms	remaining: 21.7ms
# 18:	learn: 2039.2493873	total: 204ms	remaining: 10.8ms
# 19:	learn: 2028.3103271	total: 266ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3372.0967743	total: 4.99ms	remaining: 94.9ms
# 1:	learn: 2850.0901721	total: 12.3ms	remaining: 111ms
# 2:	learn: 2598.0591684	total: 55.6ms	remaining: 315ms
# 3:	learn: 2436.4944153	total: 60.1ms	remaining: 240ms
# 4:	learn: 2353.6532274	total: 64.2ms	remaining: 193ms
# 5:	learn: 2308.7105563	total: 68.4ms	remaining: 160ms
# 6:	learn: 2257.9699209	total: 72.6ms	remaining: 135ms
# 7:	learn: 2224.8192483	total: 152ms	remaining: 228ms
# 8:	learn: 2202.4993997	total: 157ms	remaining: 191ms
# 9:	learn: 2178.3187492	total: 161ms	remaining: 161ms
# 10:	learn: 2151.3730970	total: 165ms	remaining: 135ms
# 11:	learn: 2129.7075799	total: 170ms	remaining: 113ms
# 12:	learn: 2115.5496932	total: 174ms	remaining: 93.7ms
# 13:	learn: 2106.5993379	total: 178ms	remaining: 76.4ms
# 14:	learn: 2087.7041170	total: 252ms	remaining: 83.9ms
# 15:	learn: 2078.7978746	total: 256ms	remaining: 64.1ms
# 16:	learn: 2069.7364524	total: 261ms	remaining: 46ms
# 17:	learn: 2061.1284603	total: 265ms	remaining: 29.5ms
# 18:	learn: 2053.5726663	total: 270ms	remaining: 14.2ms
# 19:	learn: 2038.8127296	total: 275ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3382.2333646	total: 4.96ms	remaining: 94.3ms
# 1:	learn: 2853.6776925	total: 9.69ms	remaining: 87.2ms
# 2:	learn: 2563.1154861	total: 58.9ms	remaining: 334ms
# 3:	learn: 2439.5803922	total: 63.5ms	remaining: 254ms
# 4:	learn: 2358.3116835	total: 67.8ms	remaining: 204ms
# 5:	learn: 2312.4808790	total: 71.9ms	remaining: 168ms
# 6:	learn: 2267.7329502	total: 76.3ms	remaining: 142ms
# 7:	learn: 2225.0594943	total: 80.8ms	remaining: 121ms
# 8:	learn: 2196.2478361	total: 89.6ms	remaining: 109ms
# 9:	learn: 2177.7973708	total: 93.8ms	remaining: 93.8ms
# 10:	learn: 2155.2423443	total: 98.3ms	remaining: 80.4ms
# 11:	learn: 2134.3653474	total: 102ms	remaining: 68.3ms
# 12:	learn: 2116.1896195	total: 107ms	remaining: 57.5ms
# 13:	learn: 2103.2008679	total: 111ms	remaining: 47.5ms
# 14:	learn: 2091.5019745	total: 115ms	remaining: 38.2ms
# 15:	learn: 2077.9997113	total: 191ms	remaining: 47.7ms
# 16:	learn: 2067.7117133	total: 195ms	remaining: 34.4ms
# 17:	learn: 2061.1617954	total: 199ms	remaining: 22.1ms
# 18:	learn: 2049.1908670	total: 203ms	remaining: 10.7ms
# 19:	learn: 2042.0103125	total: 206ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3171.3141405	total: 15.1ms	remaining: 60.5ms
# 1:	learn: 2535.0002456	total: 65.5ms	remaining: 98.2ms
# 2:	learn: 2273.1626105	total: 79.2ms	remaining: 52.8ms
# 3:	learn: 2141.1697409	total: 92.1ms	remaining: 23ms
# 4:	learn: 2071.8083481	total: 171ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3137.3920221	total: 15.6ms	remaining: 62.2ms
# 1:	learn: 2542.0696838	total: 59.7ms	remaining: 89.5ms
# 2:	learn: 2284.6791877	total: 72.4ms	remaining: 48.3ms
# 3:	learn: 2148.6868067	total: 84.8ms	remaining: 21.2ms
# 4:	learn: 2077.6141683	total: 165ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3148.3608136	total: 51.8ms	remaining: 207ms
# 1:	learn: 2551.5600079	total: 64.7ms	remaining: 97.1ms
# 2:	learn: 2280.8658509	total: 77.6ms	remaining: 51.7ms
# 3:	learn: 2161.3346993	total: 156ms	remaining: 39.1ms
# 4:	learn: 2092.3615973	total: 169ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3171.3141405	total: 13.6ms	remaining: 123ms
# 1:	learn: 2535.0002456	total: 61.9ms	remaining: 248ms
# 2:	learn: 2273.1626105	total: 75.2ms	remaining: 175ms
# 3:	learn: 2141.1697409	total: 88.3ms	remaining: 132ms
# 4:	learn: 2071.8083481	total: 169ms	remaining: 169ms
# 5:	learn: 2027.1120689	total: 182ms	remaining: 122ms
# 6:	learn: 2000.5632785	total: 260ms	remaining: 112ms
# 7:	learn: 1981.1794115	total: 274ms	remaining: 68.6ms
# 8:	learn: 1954.3181467	total: 289ms	remaining: 32.1ms
# 9:	learn: 1936.7645657	total: 363ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3137.3920221	total: 55.9ms	remaining: 503ms
# 1:	learn: 2542.0696838	total: 69.2ms	remaining: 277ms
# 2:	learn: 2284.6791877	total: 81.9ms	remaining: 191ms
# 3:	learn: 2148.6868067	total: 161ms	remaining: 241ms
# 4:	learn: 2077.6141683	total: 174ms	remaining: 174ms
# 5:	learn: 2035.2945554	total: 252ms	remaining: 168ms
# 6:	learn: 2008.9245987	total: 266ms	remaining: 114ms
# 7:	learn: 1981.7497382	total: 279ms	remaining: 69.7ms
# 8:	learn: 1956.1424776	total: 359ms	remaining: 39.9ms
# 9:	learn: 1944.5776203	total: 374ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3148.3608136	total: 13.3ms	remaining: 120ms
# 1:	learn: 2551.5600079	total: 26.5ms	remaining: 106ms
# 2:	learn: 2280.8658509	total: 70.1ms	remaining: 163ms
# 3:	learn: 2161.3346993	total: 83.3ms	remaining: 125ms
# 4:	learn: 2092.3615973	total: 161ms	remaining: 161ms
# 5:	learn: 2041.5113793	total: 174ms	remaining: 116ms
# 6:	learn: 2011.7034720	total: 188ms	remaining: 80.4ms
# 7:	learn: 1989.8297278	total: 268ms	remaining: 66.9ms
# 8:	learn: 1968.4053529	total: 281ms	remaining: 31.2ms
# 9:	learn: 1950.9611065	total: 295ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3171.3141405	total: 13.6ms	remaining: 258ms
# 1:	learn: 2535.0002456	total: 69.3ms	remaining: 623ms
# 2:	learn: 2273.1626105	total: 82.7ms	remaining: 469ms
# 3:	learn: 2141.1697409	total: 162ms	remaining: 647ms
# 4:	learn: 2071.8083481	total: 175ms	remaining: 525ms
# 5:	learn: 2027.1120689	total: 189ms	remaining: 442ms
# 6:	learn: 2000.5632785	total: 263ms	remaining: 488ms
# 7:	learn: 1981.1794115	total: 276ms	remaining: 414ms
# 8:	learn: 1954.3181467	total: 289ms	remaining: 354ms
# 9:	learn: 1936.7645657	total: 368ms	remaining: 368ms
# 10:	learn: 1924.6305416	total: 380ms	remaining: 311ms
# 11:	learn: 1909.8873747	total: 394ms	remaining: 262ms
# 12:	learn: 1889.9290208	total: 473ms	remaining: 255ms
# 13:	learn: 1881.3715043	total: 487ms	remaining: 209ms
# 14:	learn: 1873.1085674	total: 565ms	remaining: 188ms
# 15:	learn: 1865.8979257	total: 578ms	remaining: 145ms
# 16:	learn: 1853.3565303	total: 592ms	remaining: 104ms
# 17:	learn: 1848.3785649	total: 671ms	remaining: 74.6ms
# 18:	learn: 1840.4408956	total: 684ms	remaining: 36ms
# 19:	learn: 1830.6093513	total: 764ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3137.3920221	total: 13.2ms	remaining: 250ms
# 1:	learn: 2542.0696838	total: 63.6ms	remaining: 573ms
# 2:	learn: 2284.6791877	total: 76.8ms	remaining: 435ms
# 3:	learn: 2148.6868067	total: 91.2ms	remaining: 365ms
# 4:	learn: 2077.6141683	total: 169ms	remaining: 506ms
# 5:	learn: 2035.2945554	total: 182ms	remaining: 424ms
# 6:	learn: 2008.9245987	total: 194ms	remaining: 361ms
# 7:	learn: 1981.7497382	total: 271ms	remaining: 407ms
# 8:	learn: 1956.1424776	total: 285ms	remaining: 349ms
# 9:	learn: 1944.5776203	total: 364ms	remaining: 364ms
# 10:	learn: 1933.2880481	total: 377ms	remaining: 308ms
# 11:	learn: 1921.1038080	total: 390ms	remaining: 260ms
# 12:	learn: 1910.0879805	total: 469ms	remaining: 253ms
# 13:	learn: 1902.6265997	total: 482ms	remaining: 207ms
# 14:	learn: 1891.2073670	total: 496ms	remaining: 165ms
# 15:	learn: 1881.5488933	total: 570ms	remaining: 142ms
# 16:	learn: 1873.3896451	total: 582ms	remaining: 103ms
# 17:	learn: 1867.4338771	total: 662ms	remaining: 73.6ms
# 18:	learn: 1859.1523510	total: 675ms	remaining: 35.5ms
# 19:	learn: 1852.4235800	total: 689ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 3148.3608136	total: 14.4ms	remaining: 274ms
# 1:	learn: 2551.5600079	total: 67ms	remaining: 603ms
# 2:	learn: 2280.8658509	total: 80.9ms	remaining: 458ms
# 3:	learn: 2161.3346993	total: 158ms	remaining: 634ms
# 4:	learn: 2092.3615973	total: 171ms	remaining: 514ms
# 5:	learn: 2041.5113793	total: 185ms	remaining: 431ms
# 6:	learn: 2011.7034720	total: 264ms	remaining: 491ms
# 7:	learn: 1989.8297278	total: 277ms	remaining: 415ms
# 8:	learn: 1968.4053529	total: 290ms	remaining: 355ms
# 9:	learn: 1950.9611065	total: 363ms	remaining: 363ms
# 10:	learn: 1940.7717283	total: 376ms	remaining: 307ms
# 11:	learn: 1922.4931781	total: 389ms	remaining: 259ms
# 12:	learn: 1909.4705107	total: 465ms	remaining: 250ms
# 13:	learn: 1897.5239544	total: 477ms	remaining: 205ms
# 14:	learn: 1888.7815465	total: 557ms	remaining: 186ms
# 15:	learn: 1883.5440027	total: 570ms	remaining: 143ms
# 16:	learn: 1873.2858510	total: 584ms	remaining: 103ms
# 17:	learn: 1866.4426598	total: 662ms	remaining: 73.6ms
# 18:	learn: 1858.5080679	total: 676ms	remaining: 35.6ms
# 19:	learn: 1850.7765675	total: 689ms	remaining: 0us
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/.venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 5299, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 2021, in _fit
#     train_params = self._prepare_train_params(
#   File "/.venv/lib/python3.9/site-packages/catboost/core.py", line 1953, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 5839, in _catboost._check_train_params
#   File "_catboost.pyx", line 5858, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:122: Maximum tree depth is 16
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /.venv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [-2355.67220691 -2179.47287014 -2047.10584193 -2097.04469387
#  -1972.8218701  -1892.95869634            nan            nan
#             nan]
#   warnings.warn(
# Learning rate set to 0.5
# 0:	learn: 3338.8891297	total: 6.77ms	remaining: 27.1ms
# 1:	learn: 2785.9118420	total: 13.5ms	remaining: 20.2ms
# 2:	learn: 2567.9217148	total: 19.9ms	remaining: 13.3ms
# 3:	learn: 2433.5332605	total: 54ms	remaining: 13.5ms
# 4:	learn: 2347.7255090	total: 59.5ms	remaining: 0us
# Mejores parametros para CatBootRegressor : {'max_depth': 5, 'n_estimators': 5}
# RMSE con datos de entrenamiento -2355.67
# RMSE con datos de validación 3162.68
# Tiempo de entrenamiento para CatBootRegressor :
# CPU times: user 41 s, sys: 1.78 s, total: 42.8 s
# Wall time: 24.5 s

# %% [markdown]
# %% time
#
# # XGBRegressor
#
# model = XGBRegressor(random_state=12345)
# model_name = 'XGBRegressor'
#
# model_eval(model, model_name)

# %% [markdown]
# ## Análisis del modelo

# %% [markdown]
# Model	RMSE (Predicting Targets on Validation Set)	Time Required for Training + Tuning (s)	Best Hyperparameters
# LinearRegression	3162.68	15s (solo entrenamiento)	N/A
# RandomForest	3162.68	625s	max_depth=20, n_estimators=20
# LightGBM	3162.68	93s	max_depth=20, n_estimators=20
# CatBoost	3162.68	66	max_depth=15, n_estimators=15
# XGBoost	1783.36	2973	max_depth=10, n_estimators=20

# %%
# Regresion lineal

import time

start_cell = time.time()

start_train = time.time()
model = LinearRegression()
model.fit(X_train, y_train)
end_train = time.time()

elapsed_train = end_train - start_train

start_predict = time.time()
predicted_values = model.predict(X_test)
RMSE = np.sqrt(mean_squared_error(y_test, predicted_values))
print('RMSE del modelo lineal', round(RMSE,2))
end_predict = time.time()

elapsed_predict = end_predict - start_predict

print('Tiempo de entrenamiento', round(elapsed_train,2))
print('Tiempo de predicción', round(elapsed_predict,2))

end_cell = time.time()
print('Tiempo de ejecución de la celda:', round(end_cell - start_cell,2), 'seg')
# Out:
# RMSE del modelo lineal 3178.07
# Tiempo de entrenamiento 6.64
# Tiempo de predicción 0.15
# Tiempo de ejecución de la celda: 6.79 seg

# %%
# Random Forest

import time

start_cell = time.time()

start_train = time.time()
model = RandomForestRegressor(random_state=12345, n_estimators=20, max_depth=20)
model.fit(X_train, y_train)
end_train = time.time()

elapsed_train = end_train - start_train

start_predict = time.time()
predicted_values = model.predict(X_test)
RMSE = np.sqrt(mean_squared_error(y_test, predicted_values))
print('RMSE del modelo lineal', round(RMSE,2))
end_predict = time.time()

elapsed_predict = end_predict - start_predict

print('Tiempo de entrenamiento', round(elapsed_train,2))
print('Tiempo de predicción', round(elapsed_predict,2))

end_cell = time.time()
print('Tiempo de ejecución de la celda:', round(end_cell - start_cell,2), 'seg')
# Out:
# RMSE del modelo lineal 1799.24
# Tiempo de entrenamiento 51.4
# Tiempo de predicción 0.35
# Tiempo de ejecución de la celda: 51.75 seg

# %%
# CatBoost

import time

start_cell = time.time()

start_train = time.time()
model = CatBoostRegressor(random_state=12345, n_estimators=5, max_depth=5, verbose=0)
model.fit(X_train, y_train)
end_train = time.time()

elapsed_train = end_train - start_train

start_predict = time.time()
predicted_values = model.predict(X_test)
RMSE = np.sqrt(mean_squared_error(y_test, predicted_values))
print('RMSE del modelo lineal', round(RMSE,2))
end_predict = time.time()

elapsed_predict = end_predict - start_predict

print('Tiempo de entrenamiento', round(elapsed_train,2))
print('Tiempo de predicción', round(elapsed_predict,2))

end_cell = time.time()
print('Tiempo de ejecución de la celda:', round(end_cell - start_cell,2), 'seg')
# Out:
# RMSE del modelo lineal 2355.07
# Tiempo de entrenamiento 1.03
# Tiempo de predicción 0.01
# Tiempo de ejecución de la celda: 1.05 seg

# %% [markdown]
# # Conclusion
#
# Basandonos en los resultados, Rusty Bargain deberían utilizar un modelo RandomForest para sus predicciones dado a que es el que tiene menor RMSE. Sin embargo, si la preferencia es la velocidad de ejecución, el modelo a elegir debería ser CatBoost.

# %% [markdown]
# # Lista de control

# %% [markdown]
# Escribe 'x' para verificar. Luego presiona Shift+Enter

# %% [markdown]
# - [x]  Jupyter Notebook está abierto
# - [ ]  El código no tiene errores- [ ]  Las celdas con el código han sido colocadas en orden de ejecución- [ ]  Los datos han sido descargados y preparados- [ ]  Los modelos han sido entrenados
# - [ ]  Se realizó el análisis de velocidad y calidad de los modelos
