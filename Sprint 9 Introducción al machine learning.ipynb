# %% [markdown]
# ### Sprint 9: Introduccion al Machine Learning

# %%
import pandas as pd
from sklearn import set_config
from sklearn.tree import DecisionTreeClassifier

# no cambies estos parámetros de configuración
set_config(print_changed_only=False)

# importa el árbol de decisión de la librería sklearn
model = DecisionTreeClassifier()

df = pd.read_csv("E://datasets//train_data_us.csv")

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

# crea un modelo vacío y asígnalo a una variable
# entrena un modelo llamando al método fit()
model.fit(features, target)

print(model)

# %%
features.head()

# %%
target.head()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv("E://datasets//train_data_us.csv")

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier()

model.fit(features, target)

new_features = pd.DataFrame(
    [
        [None, None, 2.8, 25, None, 25, 0, 0, 0, None, 0, 30706.0, 7877.0],
        [None, None, 2.75, 25, None, 25, 0, 0, 0, None, 0, 36421.0, 9176.0]
    ],
    columns=features.columns
)

# completa la tabla con las nuevas características
new_features.loc[0, 'total_area'] = 900.0
# < escribe tu código aquí >
new_features.loc[0, 'bedrooms'] = 12
new_features.loc[0, 'living_area'] = 409.7
new_features.loc[0, 'kitchen_area'] = 112.0

new_features.loc[1, 'total_area'] = 109.0
new_features.loc[1, 'bedrooms'] = 2
new_features.loc[1, 'living_area'] = 32.0
new_features.loc[1, 'kitchen_area'] = 40.5

# predice respuestas y muestra el resultado en la pantalla
# < escribe tu código aquí >
predictions = model.predict(new_features)
print(predictions)

# %%
new_features.head()

# %% [markdown]
# ### Sprint 9.3 - Calidad del modelo

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv("E://datasets//train_data_us.csv")

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier(random_state=12345)

model.fit(features, target)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# el conjunto de entrenamiento está en el archivo train_data_us.csv 
df = pd.read_csv("E://datasets//train_data_us.csv")

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier(random_state=12345)

model.fit(features, target)

## a partir de aqui

test_df = pd.read_csv("E://datasets//test_data_us.csv")[:3]

test_df.loc[df['last_price'] > 113000, 'price_class'] = 1
test_df.loc[df['last_price'] <= 113000, 'price_class'] = 0

test_features = test_df.drop(['last_price', 'price_class'], axis=1)
test_target = test_df['price_class'].values

test_features.rename(columns={
    'balconies': 'balcony',
    'is_studio': 'studio',
    'is_open_plan': 'open_plan',
    'airport_dist': 'airports_nearest',
    'city_center_dist': 'cityCenters_nearest'
}, inplace=True)

test_features = test_features[['total_area', 
                               'bedrooms', 
                               'ceiling_height', 
                               'floors_total', 
                               'living_area', 
                               'floor', 
                               'bike_parking', 
                               'studio', 
                               'open_plan', 
                               'kitchen_area', 
                               'balcony', 
                               'airports_nearest', 
                               'cityCenters_nearest']]

test_prediction = model.predict(test_features)

print(target.head(3), test_target)

# Imprimir predicciones y respuestas correctas
print("Predicciones:", test_prediction)
print("Respuestas correctas:", test_target)

# Contar errores
errors = (test_prediction != test_target).sum()
print("Errores del modelo:", errors)

# %% [markdown]
# ### Sprint 9.4 - Exactitud

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv('E://datasets//train_data_us.csv')

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier(random_state=12345, class_weight='balanced')

model.fit(features, target)

test_df = pd.read_csv('E://datasets//test_data_us.csv')

test_df.loc[test_df['last_price'] > 113000, 'price_class'] = 1
test_df.loc[test_df['last_price'] <= 113000, 'price_class'] = 0

test_features = test_df.drop(['last_price', 'price_class'], axis=1)
test_target = test_df['price_class']

test_features.rename(columns={
    'balconies': 'balcony',
    'is_studio': 'studio',
    'is_open_plan': 'open_plan',
    'airport_dist': 'airports_nearest',
    'city_center_dist': 'cityCenters_nearest'
}, inplace=True)

test_features = test_features[['total_area', 
                               'bedrooms', 
                               'ceiling_height', 
                               'floors_total', 
                               'living_area', 
                               'floor', 
                               'bike_parking', 
                               'studio', 
                               'open_plan', 
                               'kitchen_area', 
                               'balcony', 
                               'airports_nearest', 
                               'cityCenters_nearest']]

test_predictions = model.predict(test_features)


def error_count(answers, predictions):
    count = 0
    for i in range(len(answers)):
        if answers[i] != predictions[i]:
            count += 1
    return count

print("Errores del modelo:", error_count(test_target, test_predictions))

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv('E://datasets//train_data_us.csv')

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier(random_state=12345, class_weight='balanced')

model.fit(features, target)

test_df = pd.read_csv('E://datasets//test_data_us.csv')

test_df.rename(columns={
    'balconies': 'balcony',
    'is_studio': 'studio',
    'is_open_plan': 'open_plan',
    'airport_dist': 'airports_nearest',
    'city_center_dist': 'cityCenters_nearest'
}, inplace=True)

test_df = test_df[['last_price',
                   'total_area', 
                    'bedrooms', 
                    'ceiling_height', 
                    'floors_total', 
                    'living_area', 
                    'floor', 
                    'bike_parking', 
                    'studio', 
                    'open_plan', 
                    'kitchen_area', 
                    'balcony', 
                    'airports_nearest', 
                    'cityCenters_nearest']]

test_df.loc[test_df['last_price'] > 113000, 'price_class'] = 1
test_df.loc[test_df['last_price'] <= 113000, 'price_class'] = 0

test_features = test_df.drop(['last_price', 'price_class'], axis=1)
test_target = test_df['price_class']

test_predictions = model.predict(test_features)

def error_count(answers, predictions):
    count = 0
    for i in range(len(answers)):
        if answers[i] != predictions[i]:
            count += 1
    return count

def accuracy(answers, predictions):
    return ((len(answers) - error_count(answers, predictions)) / len(answers))

print('Accuracy:', accuracy(test_target, test_predictions))
# Out:
# Accuracy: 0.8626543209876543

# %%
features.head()

# %%
test_features.head()
# Out:
#    total_area  bedrooms  ceiling_height  floors_total  living_area  floor  \
# 0        41.6         1            2.70            17         17.0      2
# 1        45.0         1            2.75            16         18.0      2
# 2        48.0         2            2.50            14         26.0     12
# 3        78.0         4            2.80             9         55.0      1
# 4        68.9         3            2.50             9         40.4      4
#
#    bike_parking  studio  open_plan  kitchen_area  balcony  airports_nearest  \
# 0             0       0          0          12.0        2             16087
# 1             0       0          0          12.0        0             32869
# 2             0       0          0           7.5        1             51610
# 3             0       0          0          10.0        2             29186
# 4             0       0          0           8.1        0             40476
#
#    cityCenters_nearest
# 0                14883
# ...

# %% [markdown]
# ### Sprint 9.6 - Métricas de evaluación en Scikit-Learn

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
# < importa la función de cálculo de precisión de la librería  sklearn >
from sklearn.metrics import accuracy_score

df = pd.read_csv('E://datasets//train_data_us.csv')

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier(random_state=12345)

model.fit(features, target)

test_df = pd.read_csv('E://datasets//test_data_us.csv')

test_df.rename(columns={
    'balconies': 'balcony',
    'is_studio': 'studio',
    'is_open_plan': 'open_plan',
    'airport_dist': 'airports_nearest',
    'city_center_dist': 'cityCenters_nearest'
}, inplace=True)

test_df = test_df[['last_price',
                   'total_area', 
                    'bedrooms', 
                    'ceiling_height', 
                    'floors_total', 
                    'living_area', 
                    'floor', 
                    'bike_parking', 
                    'studio', 
                    'open_plan', 
                    'kitchen_area', 
                    'balcony', 
                    'airports_nearest', 
                    'cityCenters_nearest']]

test_df.loc[test_df['last_price'] > 113000, 'price_class'] = 1
test_df.loc[test_df['last_price'] <= 113000, 'price_class'] = 0

test_features = test_df.drop(['last_price', 'price_class'], axis=1)
test_target = test_df['price_class']

#< escribe aquí el código para los cálculos del conjunto de entrenamiento >
train_predictions = model.predict(features)
accuracy_train = accuracy_score(target, train_predictions)

# < escribe aquí el código para los cálculos del conjunto de prueba >
test_predictions = model.predict(test_features)
accuracy_test = accuracy_score(test_target, test_predictions)

print('Exactitud')
print('Training set:', accuracy_train) # < termina el código aquí >)
print('Test set:', accuracy_test) # < termina el código aquí >)
# Out:
# Exactitud
# Training set: 0.9998460354118552
# Test set: 0.8595679012345679

# %% [markdown]
# ### Sprint 9.7 - Experimentos con árboles de decisión

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

df = pd.read_csv('E://datasets//train_data_us.csv')

df.loc[df['last_price'] > 113000, 'price_class'] = 1
df.loc[df['last_price'] <= 113000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

test_df = pd.read_csv('E://datasets//test_data_us.csv')
test_df.rename(columns={
    'balconies': 'balcony',
    'is_studio': 'studio',
    'is_open_plan': 'open_plan',
    'airport_dist': 'airports_nearest',
    'city_center_dist': 'cityCenters_nearest'
}, inplace=True)

test_df = test_df[['last_price',
                   'total_area', 
                    'bedrooms', 
                    'ceiling_height', 
                    'floors_total', 
                    'living_area', 
                    'floor', 
                    'bike_parking', 
                    'studio', 
                    'open_plan', 
                    'kitchen_area', 
                    'balcony', 
                    'airports_nearest', 
                    'cityCenters_nearest']]

test_df.loc[test_df['last_price'] > 113000, 'price_class'] = 1
test_df.loc[test_df['last_price'] <= 113000, 'price_class'] = 0

test_features = test_df.drop(['last_price', 'price_class'], axis=1)
test_target = test_df['price_class']



for depth in range(1, 11):  # selecciona el rango del hiperparámetro
    # < escribe tu código aquí >
    model = DecisionTreeClassifier(random_state=54321, max_depth=depth)
    model.fit(features, target)

    train_predictions = model.predict(features)
    accuracy_train = accuracy_score(target, train_predictions)

    test_predictions = model.predict(test_features)
    accuracy_test = accuracy_score(test_target, test_predictions)

    print("Exactitud de max_depth igual a", depth)
    print("Conjunto de entrenamiento:", accuracy_train) # calcula la puntuación de accuracy en el conjunto de entrenamiento
    print("Conjunto de prueba:", accuracy_train) # calcula la puntuación de accuracy en el conjunto de prueba
    print()
# Out:
# Exactitud de max_depth igual a 1
# Conjunto de entrenamiento: 0.8435719784449577
# Conjunto de prueba: 0.8435719784449577
#
# Exactitud de max_depth igual a 2
# Conjunto de entrenamiento: 0.8435719784449577
# Conjunto de prueba: 0.8435719784449577
#
# Exactitud de max_depth igual a 3
# Conjunto de entrenamiento: 0.8665127020785219
# Conjunto de prueba: 0.8665127020785219
#
# Exactitud de max_depth igual a 4
# Conjunto de entrenamiento: 0.8739030023094688
# Conjunto de prueba: 0.8739030023094688
#
# Exactitud de max_depth igual a 5
# Conjunto de entrenamiento: 0.891301000769823
# Conjunto de prueba: 0.891301000769823
#
# Exactitud de max_depth igual a 6
# Conjunto de entrenamiento: 0.9023864511162433
# Conjunto de prueba: 0.9023864511162433
#
# Exactitud de max_depth igual a 7
# Conjunto de entrenamiento: 0.9140877598152425
# Conjunto de prueba: 0.9140877598152425
#
# Exactitud de max_depth igual a 8
# Conjunto de entrenamiento: 0.930715935334873
# ...

# %% [markdown]
# ### Calcular EMC

# %%
def mse(answers, predictions):
    sum_squared_error = 0
    for i in range(len(answers)):
        sum_squared_error += (answers[i] - predictions[i]) ** 2
    return sum_squared_error / len(answers)
    # < escribe tu código aquí  >
    
answers = [623, 253, 150, 237]
predictions = [649, 253, 370, 148]

print(mse(answers, predictions))
# Out:
# 14249.25

# %%
from sklearn.metrics import mean_squared_error

answers = [623, 253, 150, 237]
predictions = [649, 253, 370, 148]

result = mean_squared_error(answers, predictions) # < llama a la función de cálculo de EMC >
print(result)
# Out:
# 14249.25

# %% [markdown]
# ### Interpretación del ECM

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error

df = pd.read_csv('E://datasets//train_data_us.csv')

# < crea las variables features y target >
features = df.drop(['last_price'], axis=1)
target = df['last_price']

# < calcula e imprime el promedio >
print('Average price:', sum(target)/len(target))
# Out:
# Average price: 161005.6742755966

# %%
time_list = [12, 2, 32, 19, 57, 22, 14]
sorted(time_list)

print(time_list)
# Out:
# [12, 2, 32, 19, 57, 22, 14]
