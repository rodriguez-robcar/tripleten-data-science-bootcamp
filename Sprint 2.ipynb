# %% [markdown]
# ### Sprint 2: Capitulo 1.1 Bucles - Operadores de asignación aumentada y funciones integradas

# %%
# Lista de importes de ventas diarias en dólares
daily_sales = [250.75, 300.5, 100.25, 400.0, 320.5, 200.0, 150.0]

# Calcula los ingresos totales utilizando sum() y el operador de asignación aumentada
total_revenue = sum(daily_sales)# escribe tu código aquí

# Encuentra los importes de venta más altos y más bajos usando max() y min()
highest_sales = max(daily_sales)# escribe tu código aquí
lowest_sales = min(daily_sales)# escribe tu código aquí

# Muestra los resultados
print("Ingresos totales de la semana: $", total_revenue)
print("Importe de ventas más alto en un día: $", highest_sales)
print("Importe de ventas más bajo en un día: $", lowest_sales)
# Out:
# Ingresos totales de la semana: $ 1722.0
# Importe de ventas más alto en un día: $ 400.0
# Importe de ventas más bajo en un día: $ 100.25

# %% [markdown]
# ### Sprint 2: Capitulo 1.2 Bucles for

# %%
# Ejercicio 1
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
]

# escribe tu código aquí
for client in clients:
    print(client[1])

print()

#Ejercicio 2
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"]
]

total_age = 0
num_clients = 0

# escribe tu código aquí
for client in clients:
    total_age += client[2]
    num_clients += 1

average_age = total_age/num_clients
print(average_age)
# Out:
# Jack Wilson
# Nina Brown
# Alex Smith
# Brian Perez
# Sarah Lee
# David Kim
# Samantha Chen
# Juan Rodriguez
# 35.25

# %% [markdown]
# ### Sprint 2: Capitulo 1.3 Bucles sobre listas anidadas

# %%
# Lista anidada de pedidos: [precio, cantidad, descuento]
orders = [
    [199.99, 2, 0.10],  # 10% de descuento
    [349.99, 1, 0.05],  # 5% de descuento
    [129.99, 3, 0.00],  # Sin descuento
    [499.99, 1, 0.20],  # 20% de descuento
    [249.99, 4, 0.15],  # 15% de descuento
]

# Inicializa las variables
total_revenue = 0
net_values = []

# Recorre los pedidos
for order in orders:
    price = order[0]
    quantity = order[1]
    discount = order[2]
    net_value = price * quantity * (1-discount)
    net_values.append(net_value)
    total_revenue += net_value 

highest_order_value = max(net_values)

print("Ingresos totales después de descuentos y tasas:", total_revenue) # Salida: Ingresos totales después de descuentos y tasas: 2332.4005
print("Valor de pedido único más alto:", highest_order_value)  # Salida: Valor de pedido único más alto: 849.966
# Out:
# Ingresos totales después de descuentos y tasas: 2332.4005
# Valor de pedido único más alto: 849.966

# %% [markdown]
# ### Sprint 2: Capitulo 1.4 Bucles while

# %%
annual_income = 150000 # ingreso anual de Jack
target_income = 1000000 # ingreso objetivo

total_income_sum = 0 # ingresos totales que se actualizarán para cada año
years_to_million = 0 # cantidad de años que también se actualizará

while total_income_sum < target_income:
    total_income_sum += annual_income # escribe tu código aquí
    years_to_million += 1 # escribe tu código aquí

print(years_to_million)
# Out:
# 7

# %% [markdown]
# ### Sprint 2 : Capitulo 2.1 Sentencias condicionales

# %%
text_entries = ['Hola', 'hola', '1234', "hola1234"]  # Lista de entradas de texto

for text in text_entries:
    
    print(f"Text '{text}':") 
    
    # Comprueba si el texto solo contiene caracteres alfabéticos
    print("Solo contiene alfabeto", text.isalpha()) # escribe aquí tu función de predicado
    
    # Comprueba si el texto contiene solo letras en minúscula
    print("Solo contiene minúsculas", text.islower()) # escribe aquí tu función de predicado
    
    # Comprueba si el texto contiene solo dígitos
    print("Solo contiene dígitos", text.isdigit()) # escribe aquí tu función de predicado
    
    # Comprueba si el texto es todo alfabeto o son todos dígitos
    print("Es alfabético o tiene dígitos", (text.isalpha() or text.isdigit())) # escribe aquí tus funciones de predicado con la expresión lógica
    
    # Comprueba si el texto no es todo alfabeto o no son todos dígitos
    print("No es alfabético ni tiene dígitos", not(text.isalpha() or text.isdigit()))# escribe aquí tus funciones de predicado con la expresión lógica
# Out:
# Text 'Hola':
# Solo contiene alfabeto True
# Solo contiene minúsculas False
# Solo contiene dígitos False
# Es alfabético o tiene dígitos True
# No es alfabético ni tiene dígitos False
# Text 'hola':
# Solo contiene alfabeto True
# Solo contiene minúsculas True
# Solo contiene dígitos False
# Es alfabético o tiene dígitos True
# No es alfabético ni tiene dígitos False
# Text '1234':
# Solo contiene alfabeto False
# Solo contiene minúsculas False
# Solo contiene dígitos True
# Es alfabético o tiene dígitos True
# No es alfabético ni tiene dígitos False
# Text 'hola1234':
# Solo contiene alfabeto False
# Solo contiene minúsculas True
# Solo contiene dígitos False
# Es alfabético o tiene dígitos False
# No es alfabético ni tiene dígitos True

# %% [markdown]
# ### Sprint 2: Capitulo 2.2 Sentencias if - else

# %%
# Ejercicio 1

clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"]
]

elite_clients = [] # añade elite clients aquí

# escribe tu código aquí
for client in clients:
    if client[3] > 200000:
        elite_clients.append(client)

print(elite_clients)

# Ejercicio 2

clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

# listas vacías para agregar clientes
neo = []
plus = []

# escribe tu código aquí
for client in clients:
    if client[2] < 41:
        neo.append(client)
    else:
        plus.append(client)

print(neo)
# Out:
# [[34591, 'Nina Brown', 45, 250000, 'Telecom'], [37512, 'Alex Smith', 39, 210000, 'IT'], [39591, 'Brian Perez', 29, 340000, 'Transportation'], [49571, 'Samantha Chen', 42, 220000, 'Retail']]
# [[32456, 'Jack Wilson', 32, 150000, 'Healthcare'], [37512, 'Alex Smith', 39, 210000, 'IT'], [39591, 'Brian Perez', 29, 340000, 'Transportation'], [45123, 'Sarah Lee', 28, 120000, 'Marketing'], [47635, 'David Kim', 36, 180000, 'Finance'], [50391, 'Juan Rodriguez', 31, 160000, 'Architecture'], [34556, 'Lucas Hernandez', 37, 75000, 'Education'], [64291, 'Jessica Li', 25, 125000, 'IT'], [83191, 'Sophia Perez', 34, 225000, 'Transportation'], [91023, 'Liam Kim', 29, 98000, 'Retail'], [96435, 'Ava Chen', 31, 175000, 'Marketing'], [100571, 'Noah Rodriguez', 28, 85000, 'Architecture'], [104556, 'William Brown', 38, 289000, 'Finance'], [105491, 'Emily Smith', 29, 193000, 'Healthcare']]

# %% [markdown]
# ### Sprint 2: Capitulo 2.3 Creación de múltiples ramas con else y elif

# %%
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

# listas vacías para agregar clientes
standard = []
plus = []
elite = []
executive = []

# escribe tu código aquí
for client in clients:
    if client[3] < 100000:
        standard.append(client)
    elif 100000 <= client[3] < 200000:
        plus.append(client)
    elif 200000 <= client[3] < 300000:
        elite.append(client)
    else:
        executive.append(client)

print(executive)
# Out:
# [[39591, 'Brian Perez', 29, 340000, 'Transportation'], [101321, 'Olivia Wilson', 44, 310000, 'Telecom'], [107512, 'Michael Perez', 53, 415000, 'Transportation']]

# %% [markdown]
# ### Sprint 2: Capitulo 2.4 Modificación de tablas

# %%
employees = [
    ['Alice', 75000, 'Desarrollador', 'Júnior'],
	['Bob', 68000, 'Diseñador', 'Semi sénior'],
	['Charlie', 78000, 'Desarrollador', 'Júnior'],
	['David', 85000, 'Gerente', 'Sénior'],
	['Eve', 80000, 'Desarrollador', 'Semi sénior']
]
							
# Define el nombre que actualizarás, el incremento de salario y el umbral especificado de salario para el cambio de antigüedad
name_to_update = "Alice"
salary_increase = 10000
salary_threshold = 80000
new_seniority = "Sénior"

## TU CÓDIGO ##
for employee in employees:
    if employee[0] == name_to_update:
        employee[1] += salary_increase
        if employee[1] > salary_threshold:
            employee[3] = new_seniority

# Mostrar la tabla actualizada
print(employees)
# Out:
# [['Alice', 85000, 'Desarrollador', 'Sénior'], ['Bob', 68000, 'Diseñador', 'Semi sénior'], ['Charlie', 78000, 'Desarrollador', 'Júnior'], ['David', 85000, 'Gerente', 'Sénior'], ['Eve', 80000, 'Desarrollador', 'Semi sénior']]

# %% [markdown]
# ### Sprint 2: Capitulo 2.5 Filtrar tablas

# %%
movies_info = [
    ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111],
    ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.730],
    ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499],
    ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818],
    ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625],
    ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619],
    ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521],
    ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644],
    ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106],
    ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
]

usa_movies_filtered = [] # lista vacía para almacenar el resultado

# escribe tu código aquí
for movie in movies_info:
    if movie[1] == 'USA'and movie[2] >= 1990:
        usa_movies_filtered.append([movie[0], movie[2], movie[3], movie[4], movie[5]])

# muestra el resultado
print(usa_movies_filtered )
# Out:
# [['The Shawshank Redemption', 1994, 'drama', 142, 9.111], ['The Dark Knight', 2008, 'fantasy, action, thriller', 152, 8.499], ["Schindler's List", 1993, 'drama', 195, 8.818], ['Pulp Fiction', 1994, 'thriller, comedy, crime', 154, 8.619], ['Fight Club', 1999, 'thriller, drama, crime', 139, 8.644], ['Good Will Hunting', 1997, 'drama, romance', 126, 8.077]]

# %% [markdown]
# ### Sprint 2: Capitulo 2.6 Operadores lógicos y filtros

# %%
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

standard_young = []
plus_young = []
elite_young = []
executive_young = []

for client in clients:
    if client[3] < 100000 and client[2] < 40: 
        standard_young.append(client)
    elif 100000 <= client[3] < 200000 and client[2] < 35: 
        plus_young.append(client)
    elif 200000 <= client[3] < 300000 and client[2] < 35: 
        elite_young.append(client)
    elif client[3] >= 300000 and client[2] < 35: 
        executive_young.append(client)

# no modifiques nada por debajo de esta línea
print(executive_young)
# Out:
# [[39591, 'Brian Perez', 29, 340000, 'Transportation']]

# %% [markdown]
# ### Sprint 2: Capitulo 3.2 Propiedades de los diccionarios

# %%
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

# escribe tu código aquí
# primero, crea un diccionario utilizando llaves
# luego, imprime el diccionario creado
for client in clients:
    dictionary = {
        'id' : client[0],
        'client_name' : client[1],
        'age' : client[2],
        'yearly_income' : client[3],
        'work_field' : client[4]
    }
    print(dictionary)

print()
print(dictionary)
# Out:
# {'id': 32456, 'client_name': 'Jack Wilson', 'age': 32, 'yearly_income': 150000, 'work_field': 'Healthcare'}
# {'id': 34591, 'client_name': 'Nina Brown', 'age': 45, 'yearly_income': 250000, 'work_field': 'Telecom'}
# {'id': 37512, 'client_name': 'Alex Smith', 'age': 39, 'yearly_income': 210000, 'work_field': 'IT'}
# {'id': 39591, 'client_name': 'Brian Perez', 'age': 29, 'yearly_income': 340000, 'work_field': 'Transportation'}
# {'id': 45123, 'client_name': 'Sarah Lee', 'age': 28, 'yearly_income': 120000, 'work_field': 'Marketing'}
# {'id': 47635, 'client_name': 'David Kim', 'age': 36, 'yearly_income': 180000, 'work_field': 'Finance'}
# {'id': 49571, 'client_name': 'Samantha Chen', 'age': 42, 'yearly_income': 220000, 'work_field': 'Retail'}
# {'id': 50391, 'client_name': 'Juan Rodriguez', 'age': 31, 'yearly_income': 160000, 'work_field': 'Architecture'}
# {'id': 34556, 'client_name': 'Lucas Hernandez', 'age': 37, 'yearly_income': 75000, 'work_field': 'Education'}
# {'id': 64291, 'client_name': 'Jessica Li', 'age': 25, 'yearly_income': 125000, 'work_field': 'IT'}
# {'id': 74512, 'client_name': 'Emma Davis', 'age': 47, 'yearly_income': 197000, 'work_field': 'Finance'}
# {'id': 83191, 'client_name': 'Sophia Perez', 'age': 34, 'yearly_income': 225000, 'work_field': 'Transportation'}
# {'id': 91023, 'client_name': 'Liam Kim', 'age': 29, 'yearly_income': 98000, 'work_field': 'Retail'}
# {'id': 96435, 'client_name': 'Ava Chen', 'age': 31, 'yearly_income': 175000, 'work_field': 'Marketing'}
# {'id': 100571, 'client_name': 'Noah Rodriguez', 'age': 28, 'yearly_income': 85000, 'work_field': 'Architecture'}
# {'id': 101321, 'client_name': 'Olivia Wilson', 'age': 44, 'yearly_income': 310000, 'work_field': 'Telecom'}
# {'id': 104556, 'client_name': 'William Brown', 'age': 38, 'yearly_income': 289000, 'work_field': 'Finance'}
# {'id': 105491, 'client_name': 'Emily Smith', 'age': 29, 'yearly_income': 193000, 'work_field': 'Healthcare'}
# {'id': 107512, 'client_name': 'Michael Perez', 'age': 53, 'yearly_income': 415000, 'work_field': 'Transportation'}
#
# {'id': 107512, 'client_name': 'Michael Perez', 'age': 53, 'yearly_income': 415000, 'work_field': 'Transportation'}

# %% [markdown]
# ### Sprint 2: Capitulo 3.3 Extraer valores de diccionarios

# %%
# Diccionario anidado que representa productos
products = {
    'Product_A': {'price': 10, 'quantity': 2, 'discount': 0.1},
    'Product_B': {'price': 20, 'quantity': 1, 'discount': 0.05},
    'Product_C': {'price': 15, 'quantity': 5, 'discount': 0.2},
}

# Inicializa las variables
### AQUÍ VA TU CÓDIGO ###
price = 0
quantity = 0
discount = 0
total_sales = 0
max_price = 0
max_product = ""

# Calcula los ingresos totales y encuentra el producto más caro
### AQUÍ VA TU CÓDIGO ###
for product in products:
    price = products[product]['price']
    quantity = products[product]['quantity']
    discount = products[product]['discount']
    total_sales += price*quantity*(1-discount)

    if products[product]['price'] > max_price :
        max_price = products[product]['price']
        max_product = product
    

max_price *= 0.9

print(f'Ingresos totales: ${total_sales}')
print(f'Producto más caro: {max_product} (Precio actualizado a ${max_price})')
print()
print(list(products.items()))
print()
print(products.items())
print()
print(products.keys())
print()
print(products.values())
print()
product_A = products.get('Product_A')
print(product_A.get('price'))
# Out:
# Ingresos totales: $97.0
# Producto más caro: Product_B (Precio actualizado a $18.0)
#
# [('Product_A', {'price': 10, 'quantity': 2, 'discount': 0.1}), ('Product_B', {'price': 20, 'quantity': 1, 'discount': 0.05}), ('Product_C', {'price': 15, 'quantity': 5, 'discount': 0.2})]
#
# dict_items([('Product_A', {'price': 10, 'quantity': 2, 'discount': 0.1}), ('Product_B', {'price': 20, 'quantity': 1, 'discount': 0.05}), ('Product_C', {'price': 15, 'quantity': 5, 'discount': 0.2})])
#
# dict_keys(['Product_A', 'Product_B', 'Product_C'])
#
# dict_values([{'price': 10, 'quantity': 2, 'discount': 0.1}, {'price': 20, 'quantity': 1, 'discount': 0.05}, {'price': 15, 'quantity': 5, 'discount': 0.2}])
#
# 10

# %% [markdown]
# ### Sprint 2: Capitulo 3.4 Agregar y eliminar elementos

# %%
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

incomes_per_field = {} # aquí colocarás los ingresos para cada campo

for client in clients:
	# primero, extrae el nombre del campo
	field_name = client[4]
	# segundo, extrae los ingresos
	client_income = client[3]

	# comprueba si el campo extraído NO está en el diccionario incomes_per_field
	if incomes_per_field.get(field_name) == None: #<--- use get() to ensure that no error is generated if field_name is not in dictionary 
		# añade un nuevo campo como clave y establece una lista como valor 
		incomes_per_field[field_name] = [client_income]
	else: 
		# si el campo extraído está en el diccionario incomes_per_field
		# añade el nuevo ingreso a la lista de ingresos para un campo en particular
		incomes_per_field[field_name].append(client_income)
		

# no modifiques el código de abajo, ya que imprime el resultado
print(incomes_per_field)
# Out:
# {'Healthcare': [150000, 193000], 'Telecom': [250000, 310000], 'IT': [210000, 125000], 'Transportation': [340000, 225000, 415000], 'Marketing': [120000, 175000], 'Finance': [180000, 197000, 289000], 'Retail': [220000, 98000], 'Architecture': [160000, 85000], 'Education': [75000]}

# %%
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

products = {
    'Product_A': 'A value',
    'Product_B': 'B value',
    'Product_C': 'C value'
}

print(products.get('Product_A'))
print()

print(products.get('Product_D'))
print()

for client in clients:
    client_record = client[1]
    print(client_record)

print()

for product in products:
    print(product)

books = {
        'George Orwell': '1984',
    'Leo Tolstoy': 'Guerra y paz',
    'Ralph Ellison': 'El hombre invisible',
    'Antoine de Saint-Exupéry': 'El principito'
}

for author, title in books.items():
    print(author, title)

book_inventory = []

## Funciones
def add_book(title, author, available = True):
    book_inventory.append({'title': title, 'author': author, 'available': available})

add_book("1984", "George Orwell")
add_book("To Kill a Mockingbird", "Harper Lee", available=True)
add_book("The Great Gatsby", "F. Scott Fitzgerald")

print()
print(book_inventory)
# Out:
# A value
#
# None
#
# Jack Wilson
# Nina Brown
# Alex Smith
# Brian Perez
# Sarah Lee
# David Kim
# Samantha Chen
# Juan Rodriguez
# Lucas Hernandez
# Jessica Li
# Emma Davis
# Sophia Perez
# Liam Kim
# Ava Chen
# Noah Rodriguez
# Olivia Wilson
# William Brown
# Emily Smith
# Michael Perez
#
# Product_A
# Product_B
# Product_C
# George Orwell 1984
# Leo Tolstoy Guerra y paz
# Ralph Ellison El hombre invisible
# Antoine de Saint-Exupéry El principito
#
# [{'title': '1984', 'author': 'George Orwell', 'available': True}, {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'available': True}, {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald', 'available': True}]

# %% [markdown]
# ### Sprint 2: Capitulo 4.1 - Funciones

# %%
clients_list = [
        [32456, "Jack Wilson", 32, 150000, "Healthcare"],
        [34591, "Nina Brown", 45, 250000, "Telecom"],
        [37512, "Alex Smith", 39, 210000, "IT"],
        [39591, "Brian Perez", 29, 340000, "Transportation"],
        [45123, "Sarah Lee", 28, 120000, "Marketing"],
        [47635, "David Kim", 36, 180000, "Finance"],
        [49571, "Samantha Chen", 42, 220000, "Retail"],
        [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
        [34556, "Lucas Hernandez", 37, 75000, "Education"],
        [64291, "Jessica Li", 25, 125000, "IT"],
        [74512, "Emma Davis", 47, 197000, "Finance"],
        [83191, "Sophia Perez", 34, 225000, "Transportation"],
        [91023, "Liam Kim", 29, 98000, "Retail"],
        [96435, "Ava Chen", 31, 175000, "Marketing"],
        [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
        [101321, "Olivia Wilson", 44, 310000, "Telecom"],
        [104556, "William Brown", 38, 289000, "Finance"],
        [105491, "Emily Smith", 29, 193000, "Healthcare"],
        [107512, "Michael Perez", 53, 415000, "Transportation"]]


# crea aquí tu función filter_clients
def filter_clients(field, clients_list):
    filtered_list = []
    for client in clients_list:
        if client[4] == field:
            filtered_list.append(client)

    return filtered_list


filtered_list = filter_clients("Telecom", clients_list)# Llama tu función con el parámetro "Telecom"

# muestra el resultado
print(filtered_list)
# Out:
# [[34591, 'Nina Brown', 45, 250000, 'Telecom'], [101321, 'Olivia Wilson', 44, 310000, 'Telecom']]

# %% [markdown]
# ### Sprint 2: Capitulo 4.2 - Funciones

# %%
inventory = []

## Funciones
def add_book(title, author, available = True):
    inventory.append({'title': title, 'author': author, 'available': available})


def check_availability(title):
    for book in inventory:
        if book['title'] == title:
            if book["available"]:
                print(f"'{title}' está disponible: {book['available']}")
            else:
                print(f"'{title}' no está disponible.")
            return
    print(f"'{title}' no está en el inventario.")


# Encapsular el préstamo de un libro
def lend_book(title):
    for book in inventory:
        if book["title"] == title:
            if book["available"]:
                book["available"] = False
                print(f"'{title}' ha sido prestado.")
            else:
                print(f"'{title}' ya está prestado.")
            return
    print(f"'{title}' no está en el inventario.")

# Encapsular el listado de todos los libros
def list_books(status="all"):
    for book in inventory:
        if status == "all":
            print(f"Título: {book['title']}, Autor(a): {book['author']}, Disponible: {book['available']}")
        elif status == "available" and book["available"]:
            print(f"Título: {book['title']}, Autor(a): {book['author']}, Disponible: {book['available']}")
        elif status == "lent" and not book["available"]:
            print(f"Título: {book['title']}, Autor(a): {book['author']}, Disponible: {book['available']}")

## Usar las funciones

# Agregar libros al inventario
add_book("1984", "George Orwell")
add_book("To Kill a Mockingbird", "Harper Lee", available=True)
add_book("The Great Gatsby", "F. Scott Fitzgerald")

# Comprobar la disponibilidad de un libro
check_availability("1984")
check_availability("Moby Dick")

# Prestar un libro
lend_book("1984")
lend_book("The Great Gatsby")

# Listar todos los libros
print("\nTodos los libros:")
list_books("all")

print("\nLibros disponibles:")
list_books("available")

print("\nLibros prestados:")
list_books("lent")
# Out:
# '1984' está disponible: True
# 'Moby Dick' no está en el inventario.
# '1984' ha sido prestado.
# 'The Great Gatsby' ha sido prestado.
#
# Todos los libros:
# Título: 1984, Autor(a): George Orwell, Disponible: False
# Título: To Kill a Mockingbird, Autor(a): Harper Lee, Disponible: True
# Título: The Great Gatsby, Autor(a): F. Scott Fitzgerald, Disponible: False
#
# Libros disponibles:
# Título: To Kill a Mockingbird, Autor(a): Harper Lee, Disponible: True
#
# Libros prestados:
# Título: 1984, Autor(a): George Orwell, Disponible: False
# Título: The Great Gatsby, Autor(a): F. Scott Fitzgerald, Disponible: False

# %% [markdown]
# ### Sprint 2: Capitulo 4.3 - Funciones

# %%
# esta función imprime la tabla filtrada. No modificar
def print_movie_info(data):
    for movie in data:
        print(movie)


# define tu función filter_by_year() aquí
def filter_by_year(data, year):
    movies_filter = []
    for row in data:
        if row[2] > year:
            movies_filter.append(row)
    
    return movies_filter

movies_info = [
    ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111],
    ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.730],
    ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499],
    ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818],
    ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625],
    ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619],
    ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521],
    ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644],
    ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106],
    ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
]

# A continuación tienes dos llamadas a funciones: para filtrar y para imprimir
movies_filtered = filter_by_year(movies_info, 1990)
print_movie_info(movies_filtered)
# Out:
# ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111]
# ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499]
# ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818]
# ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625]
# ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619]
# ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644]
# ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]

# %% [markdown]
# ### Sprint 2: Capitulo 4.4 - Variables globales y locales

# %%
# Diccionario global que representa los niveles de inventario actuales
inventory = {
    'manzana': 50,
    'plátano': 30,
    'naranja': 20
}

# Muestra el inventario inicial
print("Inventario inicial:", inventory)

# Función para agregar stock
def add_stock(product, quantity):
	global inventory
	if product in inventory:
		inventory[product] += quantity
		print(f"Se agrega(n) {quantity} manzana(s). Nuevo inventario: {inventory[product]}")
	else:
		inventory[product] = quantity
		print(f"Se agrega el nuevo producto {product} con {quantity} unidades. Nuevo inventario: {quantity}")

# Función para quitar stock
def remove_stock(product, quantity):
	global inventory
	if product in inventory:
		if inventory[product] >= quantity:
			inventory[product] -= quantity
			print(f"Se quita(n) {quantity} {product}(s). Nuevo inventario: {inventory[product]}")
		else:
			print(f"Stock insuficiente de naranja. No se puede(n) quitar {quantity} naranja(s).")
		return
	else:
		print(f"El producto {product} no existe en el inventario. No se puede quitar el stock.")


# Realiza operaciones de stock
add_stock('manzana', 20) # Agregar 20 manzanas
remove_stock('plátano', 10)  # Quitar 10 plátanos
remove_stock('naranja', 25)  # Intentar quitar 25 naranjas
remove_stock('uva', 5)    # Intentar quitar 5 uvas (producto no disponible en el inventario)
add_stock('kiwi', 30)
remove_stock('kiwi', 15)
# Out:
# Inventario inicial: {'manzana': 50, 'plátano': 30, 'naranja': 20}
# Se agrega(n) 20 manzana(s). Nuevo inventario: 70
# Se quita(n) 10 plátano(s). Nuevo inventario: 20
# Stock insuficiente de naranja. No se puede(n) quitar 25 naranja(s).
# El producto uva no existe en el inventario. No se puede quitar el stock.
# Se agrega el nuevo producto kiwi con 30 unidades. Nuevo inventario: 30
# Se quita(n) 15 kiwi(s). Nuevo inventario: 15
