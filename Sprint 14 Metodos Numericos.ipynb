# %%
import math

def bisect(function, left, right, error):
    # El bucle while repite el código mientras se cumpla el criterio.
    # Añadimos el criterio de parada.
    while right - left > error:
        
        middle = (left + right) /2 
        # asegúrate de que no haya ceros
        if function(left) == 0:
            return left
            
       # < escribe tu código aquí >
        if function(right) == 0:
            return right
            
        if function(middle) == 0:
            return middle
        # biseca el segmento y encuentra el nuevo
        # < escribe tu código aquí >
        if function(left) * function(middle) < 0:# < escribe tu código aquí >
            right = middle
        # < escribe tu código aquí >
        else:
            left = middle
    return left


def f1(x):
    return x ** 3 - x ** 2 - 2 * x


def f2(x):
    return (x + 1) * math.log10(x) - x ** 0.75


print(bisect(f1, 1, 4, 0.000001))
print(bisect(f2, 1, 4, 0.000001))

# %%
import numpy as np

y = np.array([0, 0, 1, 1, 0])
p = np.array([0.2, 0.4, 0.6, 0.8, 0.1])

nll = -np.sum(y * np.log10(p) + (1 - y) * np.log10(1 - p))

print(nll)
# Out:
# 0.6832750158095007

# %%
from math import log10

print(
    -(
        log10(1 - 0.2)
        + log10(1 - 0.4)
        + log10(0.6)
        + log10(0.8)
        + log10(1 - 0.1)
    )
)
# Out:
# 0.6832750158095007

# %%
#### Descenso de gradiente

import numpy as np

# Parámetro inicial
w = 0.0
# Tasa de aprendizaje
eta = 0.4

for i in range(10):
    grad = 2 * (w + 10)      # Derivada de (w + 10)^2
    w = w - eta * grad      # Actualización de w
    print(f"Iter {i+1}: w = {w:.4f}, L = {(w - 3)**2:.4f}")
# Out:
# Iter 1: w = -8.0000, L = 121.0000
# Iter 2: w = -9.6000, L = 158.7600
# Iter 3: w = -9.9200, L = 166.9264
# Iter 4: w = -9.9840, L = 168.5843
# Iter 5: w = -9.9968, L = 168.9168
# Iter 6: w = -9.9994, L = 168.9834
# Iter 7: w = -9.9999, L = 168.9967
# Iter 8: w = -10.0000, L = 168.9993
# Iter 9: w = -10.0000, L = 168.9999
# Iter 10: w = -10.0000, L = 169.0000

# %%
import numpy as np


def func(x):
    return (x[0] + x[1] - 1) ** 2 + (x[0] - x[1] - 2) ** 2


def gradient(x):
    return np.array([4 * x[0] - 6, 4 * x[1] + 2])

def gradient_descent(initialization, step_size, iterations):
    # < escribe tu código aquí >
    x = initialization

    for i in range(iterations):
        grad = gradient(x)
        x = x - step_size * grad
    
    return x

print(gradient_descent(np.array([0, 0]), 0.1, 5))
print(gradient_descent(np.array([0, 0]), 0.1, 100))
# Out:
# [ 1.38336 -0.46112]
# [ 1.5 -0.5]

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

data_train = pd.read_csv('/datasets/train_data_n.csv')
features_train = data_train.drop(['target'], axis=1)
target_train = data_train['target']

data_test = pd.read_csv('/datasets/test_data_n.csv')
features_test = data_test.drop(['target'], axis=1)
target_test = data_test['target']


class SGDLinearRegression:
    def __init__(self, step_size, epochs, batch_size):# < escribe tu código aquí >)):
        self.step_size = step_size
        # < escribe tu código aquí >)
        self.epochs = epochs
        self.batch_size = batch_size

    def fit(self, train_features, train_target):
        X = np.concatenate(
            (np.ones((train_features.shape[0], 1)), train_features), axis=1
        )
        y = train_target
        w = np.zeros(X.shape[1]) # < escribe tu código aquí >)
       # escribirás el algoritmo DGE aquí en los próximos ejercicios

        self.w = w[1:]
        self.w0 = w[0]

    def predict(self, test_features):
        
        return test_features.dot(self.w)

# ya se han superado los parámetros de entrenamiento adecuados
model = SGDLinearRegression(0.01, 1, 200)
model.fit(features_train, target_train)
pred_train = model.predict(features_train)
pred_test = model.predict(features_test)
print(r2_score(target_train, pred_train).round(5))
print(r2_score(target_test, pred_test).round(5))

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score


data_train = pd.read_csv('/datasets/train_data_n.csv')
features_train = data_train.drop(['target'], axis=1)
target_train = data_train['target']

data_test = pd.read_csv('/datasets/test_data_n.csv')
features_test = data_test.drop(['target'], axis=1)
target_test = data_test['target']


class SGDLinearRegression:
    def __init__(self, step_size, epochs, batch_size):
        self.step_size = step_size
        self.epochs = epochs
        self.batch_size = batch_size

    def fit(self, train_features, train_target):
        X = np.concatenate(
            (np.ones((train_features.shape[0], 1)), train_features), axis=1
        )
        y = train_target
        w = np.zeros(X.shape[1])
        
        for x in range(self.epochs):
            batches_count = X.shape[0] // self.batch_size# < write code here >
            for i in range(batches_count):
                begin = i * self.batch_size # < write code here >
                end = (i + 1) * self.batch_size # < write code here >
                X_batch = X[begin:end, :]
                y_batch = y[begin:end]
                
                # escribirás el paso de gradiente negativo aquí en el próximo ejercicio

        self.w = w[1:]
        self.w0 = w[0]

    def predict(self, test_features):
        return test_features.dot(self.w) + self.w0
    
model = SGDLinearRegression(0.01, 10, 100)
model.fit(features_train, target_train)
pred_train = model.predict(features_train)
pred_test = model.predict(features_test)
print(r2_score(target_train, pred_train).round(5))
print(r2_score(target_test, pred_test).round(5))
